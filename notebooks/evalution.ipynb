# %%
from tensorflow.keras.models import load_model
import sys

# %%
sys.path.append("..")

# %%
from src.train import main
import joblib

# %%
from pathlib import Path

BASE_DIR = Path.cwd().parent

print(BASE_DIR)
print((BASE_DIR / "models").exists())
# Out:
# /Users/vinaykumarmandalapu/Desktop/Programming/ml_course/deep_learning/imdb-sentiment-analysis
# True

# %%
model = load_model(BASE_DIR/"models/best_model.keras")
history = joblib.load(BASE_DIR / "models/history.pkl")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(history['accuracy'], label='training')
plt.plot(history['val_accuracy'], label="validation")
plt.xlabel("No of epochs")
plt.ylabel("Accuracy")
plt.legend()
